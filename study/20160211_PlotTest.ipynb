# %%
# !pip install pillow --upgrade
# Out:
# ...
#   Using cached Pillow-3.1.1.tar.gz
# ...
# error
#   Complete output from command /opt/conda/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-build-lhx8w3km/pillow/setup.py';exec(compile(getattr(tokenize, 'open', open)(__file__).read().replace('\r\n', '\n'), __file__, 'exec'))" bdist_wheel -d /tmp/tmpbwfstwbcpip-wheel- --python-tag cp34:
#   Single threaded build, not installing mp_compile:1 processes
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.4
#   creating build/lib.linux-x86_64-3.4/PIL
#   copying PIL/MicImagePlugin.py -> build/lib.linux-x86_64-3.4/PIL
#   copying PIL/TarIO.py -> build/lib.linux-x86_64-3.4/PIL
#   copying PIL/__init__.py -> build/lib.linux-x86_64-3.4/PIL
#   copying PIL/ImtImagePlugin.py -> build/lib.linux-x86_64-3.4/PIL
#   copying PIL/GimpPaletteFile.py -> build/lib.linux-x86_64-3.4/PIL
#   copying PIL/ImageColor.py -> build/lib.linux-x86_64-3.4/PIL
# ...

# %%
#%install_ext https://bitbucket.org/vladf/ipython-diags/raw/default/diagmagic.py
# %load_ext diagmagic
# Out:
# The diagmagic extension is already loaded. To reload it, use:
#   %reload_ext diagmagic

# %%
# %%blockdiag
# {
#     A -> B -> C -> D -> E;
# }
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-fa106dc98717> in <module>()
# ----> 1 get_ipython().run_cell_magic('blockdiag', '', '{\n    A -> B -> C -> D -> E;\n}')
#
# /opt/conda/lib/python3.4/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2291             magic_arg_s = self.var_expand(line, stack_depth)
#    2292             with self.builtin_trap:
# -> 2293                 result = fn(magic_arg_s, cell)
#    2294             return result
#    2295
#
# <decorator-gen-124> in blockdiag(self, line, cell)
#
# /opt/conda/lib/python3.4/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# ...

# %%
# !easy_install Pillow
# Out:
# Searching for Pillow
# Reading https://pypi.python.org/simple/Pillow/
# Best match: Pillow 3.1.1
# ...
# Processing Pillow-3.1.1.zip
# Writing /tmp/easy_install-92pu0k_q/Pillow-3.1.1/setup.cfg
# Running Pillow-3.1.1/setup.py -q bdist_egg --dist-dir /tmp/easy_install-92pu0k_q/Pillow-3.1.1/egg-dist-tmp-mdd2byz2
# Single threaded build, not installing mp_compile:1 processes
# ...
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.4/site-packages/setuptools-20.1.1-py3.4.egg/setuptools/sandbox.py", line 154, in save_modules
#   File "/opt/conda/lib/python3.4/site-packages/setuptools-20.1.1-py3.4.egg/setuptools/sandbox.py", line 195, in setup_context
#   File "/opt/conda/lib/python3.4/site-packages/setuptools-20.1.1-py3.4.egg/setuptools/sandbox.py", line 243, in run_setup
#   File "/opt/conda/lib/python3.4/site-packages/setuptools-20.1.1-py3.4.egg/setuptools/sandbox.py", line 273, in run
# ...

# %%
# !easy_install --version
# Out:
# setuptools 20.1.1 from /opt/conda/lib/python3.4/site-packages/setuptools-20.1.1-py3.4.egg (Python 3.4)

# %%
# !easy_install -U setuptools
# Out:
# Searching for setuptools
# Reading https://pypi.python.org/simple/setuptools/
# Best match: setuptools 20.1.1
# ...
# Processing setuptools-20.1.1.zip
# Writing /tmp/easy_install-k1t4q875/setuptools-20.1.1/setup.cfg
# Running setuptools-20.1.1/setup.py -q bdist_egg --dist-dir /tmp/easy_install-k1t4q875/setuptools-20.1.1/egg-dist-tmp-attwdrrm
# ...
# Moving setuptools-20.1.1-py3.4.egg to /opt/conda/lib/python3.4/site-packages
# Adding setuptools 20.1.1 to easy-install.pth file
# Installing easy_install-3.4 script to /opt/conda/bin
# Installing easy_install script to /opt/conda/bin
#
# Installed /opt/conda/lib/python3.4/site-packages/setuptools-20.1.1-py3.4.egg
# Processing dependencies for setuptools
# Finished processing dependencies for setuptools

# %%
import xlwt
import matplotlib as mpl
import numpy as np

# %%
# %matplotlib inline

# %%
x=np.arange(0, 10, 0.1) # 0から10まで0.1刻みで。
y=np.sin(x)

# %%
mpl.pylab.plot(x,y)

# %%
mpl.pyplot.imshow(np.random.randn(100, 100))
