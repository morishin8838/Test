# %% [markdown]
# # 光学シュミレーション 幾何光学
#
# > このモジュールを使うと、光学シュミレーションができます。
# > すばらしい！
#
# [参考ページ:Opticspy](http://opticspy.org/)

# %%
import sys
sys.path.append('/opt/conda/lib/python3.4/site-packages/opticspy-0.2.1-py3.4.egg/opticspy/')
sys.path.append('/opt/conda/lib/python3.4/site-packages/opticspy-0.2.1-py3.4.egg/opticspy/ray_tracing/')

# %%
# %matplotlib inline
import opticspy.ray_tracing.lens  as LNS
from opticspy.ray_tracing import *

# %%
New_Lens = LNS.Lens(lens_name='Triplet',creator='XF')
New_Lens.FNO = 5
New_Lens.lens_info()
# Out:
# Triplet
# XF

# %%
New_Lens.add_wavelength(wl = 656.30)
New_Lens.add_wavelength(wl = 587.60)
New_Lens.add_wavelength(wl = 486.10)
New_Lens.list_wavelengths()
# Out:
# Add wavelength 656.3nm done
# Add wavelength 587.6nm done
# Add wavelength 486.1nm done
# List all wavelength information
# ('Wavelength', 486.1, 'nm')
# ('Wavelength', 587.6, 'nm')
# ('Wavelength', 656.3, 'nm')

# %%
New_Lens.add_field_YAN(angle=0)
New_Lens.add_field_YAN(angle=14)
New_Lens.add_field_YAN(angle=20)
New_Lens.list_fields()
# Out:
# Add field angle:0 degree done
# Add field angle:14 degree done
# Add field angle:20 degree done
# list all fields information
# ('Field angle:', 0)
# ('Field angle:', 14)
# ('Field angle:', 20)

# %%
New_Lens.add_surface(number=1,radius=10000000,thickness=1000000,glass='air')
New_Lens.add_surface(number=2,radius=41.15909,thickness=6.097555 ,glass='S-BSM18_ohara')
New_Lens.add_surface(number=3,radius=-957.83146,thickness=9.349584,glass='air')
New_Lens.add_surface(number=4,radius=-51.32104,thickness=2.032518,glass='N-SF2_schott')
New_Lens.add_surface(number=5,radius=42.37768 ,thickness=5.995929 ,glass='air')
New_Lens.add_surface(number=6,radius=10000000,thickness=4.065037,glass='air',STO=True)
New_Lens.add_surface(number=7,radius=247.44562,thickness=6.097555,glass='S-BSM18_ohara')
New_Lens.add_surface(number=8,radius=-40.04016,thickness=85.593426,glass='air')
New_Lens.add_surface(number=9,radius=10000000,thickness=0,glass='air')
# Out:
# -----------------------Add surface:-------------------------------
# ------------------------------------------------------------------
# | Num   |  Radius     |  Thickness   |  Glass           |  STO   |
# ------------------------------------------------------------------
# | 1     |  10000000   |  1000000     |  air             |  False |
# ------------------------------------------------------------------
# -----------------------Add surface:-------------------------------
# ------------------------------------------------------------------
# | Num   |  Radius     |  Thickness   |  Glass           |  STO   |
# ------------------------------------------------------------------
# | 2     |  41.15909   |  6.097555    |  S-BSM18_ohara   |  False |
# ------------------------------------------------------------------
# -----------------------Add surface:-------------------------------
# ------------------------------------------------------------------
# ...

# %%
New_Lens.refresh_paraxial()
# Out:
# ------------Calculating EFL---------------
# ('start surface:', 2)
# ('end surface:', 8)
# ("Rear Focal Length f':", 100.00090219464373)
# ---------Calculating Entrance Pupil Position-----------
# ('STOP Surface', 6)
# ('STOP thickness', 5.995929)
# ('start surface:', 2)
# ('end surface:', 5)
# ('entrance pupil position EP:', 27.821660438933492)
# ------------Calculating OAL---------------
# ('start surface:', 2)
# ('end surface:', 9)
# ('Overall length:', 119.23160399999999)

# %%
import opticspy.ray_tracing.trace_m  as TRS
import opticspy.ray_tracing.draw  as XXX

# %%
dict_list = TRS.trace_draw_ray(New_Lens)
XXX.draw_system(New_Lens)
# Out:
# ------------------start drawing lens system-------------

# %%
#field.grid_generator(12,grid_type='grid',output = 1)
field.grid_generator(6,grid_type='grid',output = 1)
# Out:
# 0

# %%
analysis.spotdiagram(New_Lens,[1,2,3],[1,2,3],n=12,grid_type='grid')
# Out:
# ('RMS', 0.28696059788558376)
# ('RMS', 0.52450337010021331)
# ('RMS', 1.0897134423286856)
# 0

# %%
field.grid_generator(6,grid_type='circular',output = 1)
# Out:
# 0

# %%
analysis.spotdiagram(New_Lens,[1,2,3],[1,2,3],n=6,grid_type='circular')
# Out:
# ('RMS', 0.44798467593529478)
# ('RMS', 0.75250693805387137)
# ('RMS', 1.6537425439233633)
# 0

# %%
analysis.Ray_fan(New_Lens,[1,2,3],[1,2,3])
# Out:
# 0

# %% [markdown]
# #  Real Ray Tracing Example: F/5 Double Gauss

# %%
New_Lens = lens.Lens(lens_name='Doublegauss',creator='XF')
New_Lens.FNO = 5
New_Lens.lens_info()
# Out:
# Doublegauss
# XF

# %%
New_Lens.add_wavelength(wl = 656.30)
New_Lens.add_wavelength(wl = 587.60)
New_Lens.add_wavelength(wl = 486.10)
# Out:
# Add wavelength 656.3nm done
# Add wavelength 587.6nm done
# Add wavelength 486.1nm done

# %%
New_Lens.add_field_YAN(angle=0)
New_Lens.add_field_YAN(angle=10)
New_Lens.add_field_YAN(angle=14)
# Out:
# Add field angle:0 degree done
# Add field angle:10 degree done
# Add field angle:14 degree done

# %%
New_Lens.add_surface(number=1,radius=10000000,thickness=10000000,glass='air')
New_Lens.add_surface(number=2,radius=56.20238,thickness=8.75 ,glass='N-SSK2_schott')
New_Lens.add_surface(number=3,radius=152.28580,thickness=0.5,glass='air')
New_Lens.add_surface(number=4,radius=37.68262,thickness=12.5,glass='N-SK2_schott')
New_Lens.add_surface(number=5,radius=10000000 ,thickness=3.8 ,glass='F5_schott')
New_Lens.add_surface(number=6,radius=24.23130,thickness=16.369445,glass='air')
New_Lens.add_surface(number=7,radius=10000000,thickness=13.747957,glass='air',STO=True)
New_Lens.add_surface(number=8,radius=-28.37731,thickness=3.8,glass='F5_schott')
New_Lens.add_surface(number=9,radius=100000000,thickness=11,glass='N-SK16_schott')
New_Lens.add_surface(number=10,radius=-37.92546,thickness=0.5,glass='air')
New_Lens.add_surface(number=11,radius=177.41176,thickness=7,glass='N-SK16_schott')
New_Lens.add_surface(number=12,radius=-79.41143,thickness=61.487536,glass='air')
New_Lens.add_surface(number=13,radius=100000000,thickness=0,glass='air')
# Out:
# -----------------------Add surface:-------------------------------
# ------------------------------------------------------------------
# | Num   |  Radius     |  Thickness   |  Glass           |  STO   |
# ------------------------------------------------------------------
# | 1     |  10000000   |  10000000    |  air             |  False |
# ------------------------------------------------------------------
# -----------------------Add surface:-------------------------------
# ------------------------------------------------------------------
# | Num   |  Radius     |  Thickness   |  Glass           |  STO   |
# ------------------------------------------------------------------
# | 2     |  56.20238   |  8.75        |  N-SSK2_schott   |  False |
# ------------------------------------------------------------------
# -----------------------Add surface:-------------------------------
# ------------------------------------------------------------------
# ...

# %%
import opticspy.ray_tracing.trace_m  as TRS
import opticspy.ray_tracing.draw  as XXX
New_Lens.refresh_paraxial()
New_Lens.solve_imageposition()
TRS.trace_draw_ray(New_Lens)
XXX.draw_system(New_Lens)
# Out:
# ------------Calculating EFL---------------
# ('start surface:', 2)
# ('end surface:', 21)
# ("Rear Focal Length f':", -0.0010000485168507188)
# ---------Calculating Entrance Pupil Position-----------
# ('STOP Surface', 6)
# ('STOP thickness', 5.995929)
# ('STOP Surface', 7)
# ('STOP thickness', 4.065037)
# ('start surface:', 2)
# ('end surface:', 6)
# ('entrance pupil position EP:', 33.716404546907363)
# ------------Calculating OAL---------------
# ('start surface:', 2)
# ('end surface:', 22)
# ('Overall length:', 10000258.687396027)
# ------------Calculating image position---------------
# ('object distance', -1000000)
# ('start surface:', 2)
# ('end surface:', 21)
# ('image position:', 61.488390024975423)
# ------------------start drawing lens system-------------
