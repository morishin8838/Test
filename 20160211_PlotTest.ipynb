# %%
import xlwt
import matplotlib as mpl
import numpy as np

# %%
# %matplotlib inline

# %%
x=np.arange(0, 10, 0.1) # 0から10まで0.1刻みで。
y=np.sin(x)

# %%
mpl.pylab.plot(x,y)

# %%
mpl.pyplot.imshow(np.random.randn(100, 100))
