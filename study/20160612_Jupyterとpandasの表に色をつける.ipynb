# %%
# !sudo apt-get -y install python3-blockdiag
# Out:
# E: Could not get lock /var/lib/dpkg/lock - open (11: Resource temporarily unavailable)
# E: Unable to lock the administration directory (/var/lib/dpkg/), is another process using it?

# %%
import pandas as pd
import numpy as np

np.__version__
# '1.10.1'

pd.__version__
# u'0.17.1'

np.random.seed(1)

df = pd.DataFrame({'name': list('abcdefg'),
                   'values1': np.random.randn(7), 
                   'values2': np.random.randn(7)})
df
# Out:
#   name   values1   values2
# 0    a  1.624345 -0.761207
# 1    b -0.611756  0.319039
# 2    c -0.528172 -0.249370
# 3    d -1.072969  1.462108
# 4    e  0.865408 -2.060141
# 5    f -2.301539 -0.322417
# 6    g  1.744812 -0.384054

# %%
type(df.style)
# pandas.core.style.Styler

df.style.background_gradient(cmap='winter')
# Out:
#         <style  type="text/css" >
#
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row0_col1 {
#
#                 background-color:  #00f883;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row0_col2 {
#
#                 background-color:  #005ed0;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row1_col1 {
#
#                 background-color:  #006aca;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row1_col2 {
#
#                 background-color:  #00aca9;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row2_col1 {
#
#                 background-color:  #0070c7;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row2_col2 {
#
#                 background-color:  #0083be;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row3_col1 {
#
#                 background-color:  #004dd8;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row3_col2 {
#
#                 background-color:  #00ff80;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row4_col1 {
#
#                 background-color:  #00c89b;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row4_col2 {
#
#                 background-color:  #0000ff;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row5_col1 {
#
#                 background-color:  #0000ff;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row5_col2 {
#
#                 background-color:  #007ec0;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row6_col1 {
#
#                 background-color:  #00ff80;
#
#             }
#
#             #T_8dde0c24_4635_11e6_8c0f_0242ac110002row6_col2 {
#
#                 background-color:  #0079c2;
#
#             }
#
#         </style>
#
#         <table id="T_8dde0c24_4635_11e6_8c0f_0242ac110002" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">name
#
#                 <th class="col_heading level0 col1">values1
#
#                 <th class="col_heading level0 col2">values2
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_8dde0c24_4635_11e6_8c0f_0242ac110002" class="row_heading level2 row0">
#
#                         0
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row0_col0" class="data row0 col0">
#
#                         a
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row0_col1" class="data row0 col1">
#
#                         1.624345
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row0_col2" class="data row0 col2">
#
#                         -0.761207
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_8dde0c24_4635_11e6_8c0f_0242ac110002" class="row_heading level2 row1">
#
#                         1
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row1_col0" class="data row1 col0">
#
#                         b
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row1_col1" class="data row1 col1">
#
#                         -0.611756
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row1_col2" class="data row1 col2">
#
#                         0.319039
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_8dde0c24_4635_11e6_8c0f_0242ac110002" class="row_heading level2 row2">
#
#                         2
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row2_col0" class="data row2 col0">
#
#                         c
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row2_col1" class="data row2 col1">
#
#                         -0.528172
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row2_col2" class="data row2 col2">
#
#                         -0.24937
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_8dde0c24_4635_11e6_8c0f_0242ac110002" class="row_heading level2 row3">
#
#                         3
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row3_col0" class="data row3 col0">
#
#                         d
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row3_col1" class="data row3 col1">
#
#                         -1.072969
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row3_col2" class="data row3 col2">
#
#                         1.462108
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_8dde0c24_4635_11e6_8c0f_0242ac110002" class="row_heading level2 row4">
#
#                         4
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row4_col0" class="data row4 col0">
#
#                         e
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row4_col1" class="data row4 col1">
#
#                         0.865408
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row4_col2" class="data row4 col2">
#
#                         -2.060141
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_8dde0c24_4635_11e6_8c0f_0242ac110002" class="row_heading level2 row5">
#
#                         5
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row5_col0" class="data row5 col0">
#
#                         f
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row5_col1" class="data row5 col1">
#
#                         -2.301539
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row5_col2" class="data row5 col2">
#
#                         -0.322417
#
#
#             </tr>
#
#             <tr>
#
#                 <th id="T_8dde0c24_4635_11e6_8c0f_0242ac110002" class="row_heading level2 row6">
#
#                         6
#
#
#                 <td id="T_8dde0c24_4635_11e6_8c0f_0242ac110002row6_col0" class="data row6 col0">
#
#                         g
